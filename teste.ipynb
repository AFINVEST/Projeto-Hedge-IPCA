# %%
from pathlib import Path
import pandas as pd

ARQUIVO_EXCEL = "Dados/debentures-precos-05-02-2026-19-47-15.xlsx"

df = pd.read_excel(ARQUIVO_EXCEL)

colunas_necessarias = {"Código", "Tipo Remuneração"}
colunas_faltantes = colunas_necessarias - set(df.columns)

if colunas_faltantes:
    raise ValueError(f"Colunas ausentes no arquivo: {colunas_faltantes}")

mask_ipca = (
    df["Tipo Remuneração"]
    .astype(str)
    .str.contains("IPCA", case=False, na=False)
)

ativos = (
    df.loc[mask_ipca, "Código"]
    .dropna()
    .astype(str)
    .unique()
    .tolist()
)

# ======================================================
# RESULTADO
# ======================================================
print(f"Total de debêntures IPCA encontradas: {len(ativos)}")
print(ativos)
# Out:
# c:\Users\emanuel.cabral\AppData\Local\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Total de debêntures IPCA encontradas: 628
# ['AGVF12', 'AURP12', 'BARU11', 'BCPSA5', 'BTCL12', 'CBAN52', 'CCPV11', 'CEAL21', 'CEAP17', 'CEEBB6', 'CEEBC3', 'CEEBD2', 'CGOS24', 'CLCD27', 'CPLD37', 'CSMGB9', 'CSMGE1', 'CSNAB4', 'CTEE1B', 'CUTI11', 'EDPA11', 'EEELA1', 'EGIEA1', 'EGVG21', 'EKTRC1', 'ENEV15', 'ENGIB0', 'ENJG21', 'ENMTA5', 'ENSEA1', 'EQTC11', 'EQTR21', 'EQTS11', 'ERDVB4', 'ESSDB5', 'ESULA6', 'ETBA12', 'ETEN22', 'FLCLA9', 'GASC17', 'GASC27', 'JALL14', 'JSMLB5', 'LIGHB6', 'LIGHC4', 'MEZ511', 'MOVI18', 'MRSAA2', 'MRSAB2', 'MVLV16', 'OMGE12', 'PEJA11', 'PEJA23', 'PETR28', 'RENTD1', 'RESA14', 'RIPR22', 'RIS412', 'RISP22', 'RMSA12', 'RSAN26', 'RSAN34', 'RUMOA5', 'SAELA7', 'SBSPC4', 'SUMI17', 'TAEE17', 'TEPA12', 'TPNO12', 'TSSG21', 'ULFT14', 'VAMO34', 'VERO12', 'VLIM18', 'ACRC21', 'AESLA7', 'AESLB0', 'ANET12', 'APPSA2', 'ASAB11', 'BION17', 'CAEC12', 'CART13', 'CEAP12', 'CEED13', 'CEED21', 'CEPEC1', 'CERR18', 'CESPA2', 'CGASB4', 'CGEE13', 'CGMG18', 'CGOS16', 'CJEN13', 'CMGDB0', 'CMIN11', 'CPFPA5', 'CPGTC0', 'CPLDC0', 'CSNAB5', 'CSNAC4', 'CSRN29', 'CSRNB2', 'CTNSA3', 'CTRR11', 'DESK19', 'EDTE12', 'EDVP17', 'EGIE39', 'EGVG11', 'EKTT11', 'ELDC15', 'ELPLA5', 'ELTN27', 'ELTN37', 'ENAT11', 'ENERA1', 'ENERB4', 'ENEVA0', 'ENGIA4', 'ENGIA6', 'ENGIA9', 'ENGIB9', 'ENMI21', 'ENMTD2', 'ERDVC3', 'FEPS11', 'FRAG14', 'GASC19', 'GASP19', 'HBSA21', 'IRJS14', 'ITPO14', 'IVIAA0', 'JALL13', 'LIGH2B', 'LIGHC3', 'NMCH11', 'NRTB21', 'NTSD19', 'ORIG11', 'PALFB6', 'PETR27', 'PRPO12', 'PRTE12', 'QUAT13', 'RESA27', 'RUMOA7', 'SAELA3', 'SAUC14', 'SBSPB6', 'SUMI37', 'SUZBA0', 'TAEE26', 'TAEEB8', 'TBLE26', 'TCII11', 'TIMS12', 'TNHL11', 'TPEN11', 'TPNO13', 'TUPW21', 'USAS11', 'USAS22', 'UTPS21', 'VALE48', 'VALED1', 'VERO44', 'XNGU17', 'CASN24', 'CEAL12', 'CEED12', 'CERT11', 'CGOS28', 'ESAM14', 'GASC18', 'SAELA1', 'SAELB3', 'SUZB19', 'TAEEB0', 'TBEG11', 'VLIM17', 'ALGAB1', 'ALGTA4', 'ALIG12', 'ALUP18', 'APFD19', 'BHSA11', 'CBAN32', 'CCLS11', 'CDES11', 'CEPEA7', 'CESE32', 'CGASA4', 'CLAG15', 'CMIN22', 'COCE18', 'COCEB2', 'COMR14', 'CPFPB1', 'CPGT28', 'CPIS14', 'CRNP13', 'CRTA12', 'CRTR12', 'EEELA0', 'EGIEB4', 'ELPLA7', 'ELTN15', 'ENEV16', 'ENEVB0', 'ENMTC6', 'ENMTE6', 'EQUA11', 'ERDV38', 'FGEN13', 'FRAG16', 'GASP29', 'GRRB24', 'GSTS24', 'HZTC14', 'JALL24', 'LCAMD3', 'LGEN11', 'LTTE15', 'MRSAA3', 'MSGT12', 'OMGE22', 'OMGE31', 'OMNG12', 'ORIG12', 'PASN12', 'PAXA12', 'PEJA22', 'RAIZ23', 'RATL11', 'RESA17', 'RSAN16', 'RUMOA4', 'RUMOA6', 'SAPRA3', 'SERI11', 'SMTO15', 'STRZ11', 'TAEEA7', 'TAEEB2', 'TAEEC2', 'TRGO11', 'TVVH11', 'UNTE11', 'UTPS22', 'VLIM13', 'VRDN12', 'AESLA5', 'AGEO15', 'ALGAC2', 'ANET11', 'APRB18', 'ARTRA7', 'ARTRA8', 'ATHT11', 'BTEL23', 'CASN34', 'CCROB6', 'CEAP19', 'CEED19', 'CEPEB3', 'CEPEB7', 'CEROB4', 'CESPA3', 'CGOS13', 'CMGDB4', 'CMIN12', 'CPFPA2', 'CPFPA9', 'CPFPB0', 'CPFPB7', 'CSMGA6', 'CSNAA5', 'CYAR11', 'ECER12', 'EDFT11', 'EDPT11', 'EGIEB5', 'EKTRB3', 'ELPLC8', 'ENAT12', 'ENAT24', 'ENEV39', 'ENGI39', 'ENMTA3', 'ENMTC5', 'ENMTD5', 'ENSEB4', 'ENSEC4', 'ENTV12', 'EQMAA2', 'ERDVC4', 'ESCEA5', 'EUBE11', 'GASC28', 'HARG11', 'HBSA11', 'HVSP11', 'ITPO15', 'KLBNA5', 'LCAMD1', 'LIGHB7', 'LIGHC6', 'LIGHE2', 'MOTVB9', 'MRSAB1', 'MRSAC2', 'NNAE12', 'NTEN11', 'PALFA3', 'RAIZ13', 'RDOE18', 'RESA15', 'RIGEA3', 'RIS424', 'RISP12', 'RISP24', 'RLMS13', 'RSAN44', 'RUMOA3', 'SABP12', 'SBSPC6', 'SBSPE9', 'TAEE18', 'TAEEA4', 'TAEEB4', 'TAEED2', 'TIET39', 'UTPS12', 'VDBF12', 'VERO25', 'VLIM16', 'VLIM27', 'VLIM28', 'WDPR11', 'AEAB11', 'AESLA9', 'AESOA1', 'ALIG13', 'ALIG15', 'ASCP13', 'ASSR21', 'AURE12', 'AURP13', 'BRFS31', 'BRST11', 'CAJS11', 'CBAN72', 'CEAM11', 'CEEBB7', 'CEEBC4', 'CEPEC2', 'CMGD27', 'CMGD28', 'CMGDB2', 'CMGTB1', 'CONX12', 'CPGT27', 'CPIS13', 'CPLD29', 'CSMGB4', 'CSMGB8', 'CSMGC0', 'CSNAA6', 'CSNAB6', 'CSRNC0', 'CTGE11', 'CTGE15', 'DESK17', 'EBENA8', 'ECHP11', 'ECHP12', 'ECOV16', 'EGIE29', 'EGIE49', 'EKTRB6', 'EKTRC0', 'ELTE12', 'ENAT33', 'ENGIC0', 'ENMTB3', 'ENMTB5', 'EQMAA0', 'EQPA18', 'EQSP21', 'EQTR11', 'GASC26', 'HGLB23', 'ISAEC0', 'MRSAC1', 'NRTB11', 'ODYA11', 'PALF38', 'PALFA7', ...
